# %% [markdown]
# # Linear probing on VTAB-1k (RepAdapter bundle) from a Barlow Twins ViT-Tiny/8 checkpoint
#
# Same protocol as [cifar-finetuning.ipynb](cifar-finetuning.ipynb): freeze the Barlow Twins
# backbone, extract pre-logit features once, and train a fresh per-task linear
# classifier on the cached features (SGD, momentum 0.9, weight-decay 0, cosine LR,
# base LR 0.1 scaled by `batch_size/256`).
#
# **Data:** the RepAdapter **VTAB-1k** bundle under `vtab-1k/`. For every task the
# linear head is trained on the **`train800val200`** split (1000 images) and evaluated
# on the full **`test`** split — the canonical VTAB-1k protocol.
#
# **Tasks (this part):**
#
# Images are resized to 64x64 to match the backbone (patch_size=8 -> 8x8 = 64 tokens).
# These are VTAB-1k numbers (1000 training images), so they track this model but are
# not directly comparable to published 224px results.

# %% [markdown]
# ## 1. Imports

# %%
import math
import os
import random
import time

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
from torchvision.datasets.folder import default_loader

from models.barlow_twins import BarlowTwinsViT

# %% [markdown]
# ## 2. Configuration
#
# Set `pretrained` to your Barlow Twins ViT-Tiny/8 checkpoint. `data_root` points at the
# RepAdapter VTAB-1k bundle. The `VTAB_TASKS` registry (bundle folder + class count)
# is the only per-task variation -- everything downstream is task-agnostic.

# %%
class Config:
    # path to a Barlow Twins ViT-Tiny/8 checkpoint
    pretrained = 'checkpoints/e97d41c-dirty-curve/bt_split100000_seed42_best.pt'

    # RepAdapter VTAB-1k bundle root
    data_root = 'vtab-1k'
    train_split = 'train800val200'   # 1000 images
    test_split = 'test'

    # must match the pretrained backbone (patch_size=8, grid 8x8 = 64 tokens)
    image_size = 64

    # linear probing recipe -- main_lincls.py defaults
    epochs = 90
    batch_size = 256
    lr = 0.1            # base LR; scaled by batch_size/256
    momentum = 0.9
    weight_decay = 0.0
    workers = 2

    seed = 1205


args = Config()

# VTAB-1k task folders (the bundle dir name doubles as the label). num_classes is
# auto-derived from the labels. All 19 VTAB tasks, grouped by category:
VTAB_TASKS = [
    # natural
    'caltech101', 'cifar', 'dtd', 'oxford_flowers102', 'oxford_iiit_pet', 'sun397', 'svhn',
    # specialized
    'eurosat', 'patch_camelyon', 'resisc45', 'diabetic_retinopathy',
    # structured
    'clevr_count', 'clevr_dist', 'dmlab', 'kitti',
    'dsprites_loc', 'dsprites_ori', 'smallnorb_azi', 'smallnorb_ele',
]
# VTAB_TASKS=['cifar']

if args.seed is not None:
    random.seed(args.seed)
    torch.manual_seed(args.seed)
    cudnn.deterministic = True

# %% [markdown]
# ## 3. Build model and load the Barlow Twins checkpoint (shared frozen backbone)
#
# The backbone is frozen and we read **pre-logit** features via `forward_features` ->
# `forward_head(pre_logits=True)` (CLS-token pool + final norm, stops before the
# classifier). So `num_classes` here is irrelevant and the *same* frozen backbone
# serves every task. Loading rebuilds `BarlowTwinsViT` at the checkpoint's projector width and
# `load_state_dict`s the saved weights (mirrors `leo_protocol_eval.py`).

# %%
# pick the best available device -- CUDA > MPS (Apple Silicon) > CPU
if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')
print(f'=> using device: {device}')

# Build the Barlow Twins ViT-Tiny/8 backbone and load the pretrained checkpoint.
# The probe reads the 192-d CLS embedding (model.embed); the projector is loaded but
# unused, so it is rebuilt at the checkpoint's saved width. Mirrors leo_protocol_eval.py.
assert os.path.isfile(args.pretrained), f"no checkpoint at '{args.pretrained}'"
print(f"=> loading checkpoint '{args.pretrained}'")
checkpoint = torch.load(args.pretrained, map_location='cpu', weights_only=False)

# older checkpoints predate the --projector_dim flag -> default 1024
proj_dim = checkpoint.get('args', {}).get('projector_dim', 1024)
print(f"=> creating model 'BarlowTwinsViT' (ViT-Tiny/8, projector_dim={proj_dim})")
model = BarlowTwinsViT(projector_hidden=proj_dim, projector_out=proj_dim)

# strict load: the saved state_dict (backbone.* + projector.*) must match exactly
msg = model.load_state_dict(checkpoint['model_state_dict'], strict=True)
print(f'   strict load OK (missing={list(msg.missing_keys)}, unexpected={list(msg.unexpected_keys)})')

# freeze the entire backbone (linear probe on frozen features)
for _, param in model.named_parameters():
    param.requires_grad = False

ck = checkpoint.get('args', {})
print(f"=> loaded BT backbone (split={ck.get('split')}, seed={ck.get('seed')}, "
      f"global_step={checkpoint.get('global_step')}, best_knn_acc={checkpoint.get('best_knn_acc')})")

model = model.to(device)
model.eval()
cudnn.benchmark = True
# Out:
# => using device: cuda
# => loading checkpoint 'checkpoints/e97d41c-dirty-curve/bt_split100000_seed42_best.pt'
# => creating model 'BarlowTwinsViT' (ViT-Tiny/8, projector_dim=1024)
#    strict load OK (missing=[], unexpected=[])
# => loaded BT backbone (split=100000, seed=42, global_step=288400, best_knn_acc=0.2832)

# %% [markdown]
# ## 4. VTAB-1k data loader (disk-backed)
#
# Each task folder holds split lists `train800val200.txt` / `test.txt` whose lines are
# `images/<split>/NNNNNN.jpg <label>`. `VtabImageDataset` keeps only the `(path, label)`
# list and loads each image lazily in `__getitem__` via torchvision's `default_loader`
# (open + `convert('RGB')`) -- the disk-backed, ImageFolder-style replacement for the old
# in-RAM cached dataset, so no decoded images are kept in memory. `num_classes` is
# derived from the labels (max over train+test) instead of hardcoded, and the train-side
# split sizes are sanity-checked on load.

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

eval_transform = transforms.Compose([
    transforms.Resize((args.image_size, args.image_size)),
    transforms.ToTensor(),
    normalize,
])

# expected sizes for the VTAB-1k train-side splits (cheap integrity check)
_SPLIT_SIZES = {'train800': 800, 'val200': 200, 'train800val200': 1000}


class VtabImageDataset(torch.utils.data.Dataset):
    """Disk-backed VTAB-1k split. Stores only the (image path, label) list and
    loads + transforms each image lazily in __getitem__ via torchvision's
    default_loader -- the ImageFolder pattern, driven by the bundle's
    `<split>.txt` label file (the bundle has no class-named subdirs). No decoded
    images are held in RAM; the DataLoader streams them per batch."""

    def __init__(self, root, task_dir, split, transform):
        base = os.path.join(root, task_dir)
        self.transform = transform
        with open(os.path.join(base, f'{split}.txt')) as f:
            lines = f.read().splitlines()
        self.samples = [(os.path.join(base, rel), int(lab))
                        for rel, lab in (ln.split() for ln in lines)]
        if split in _SPLIT_SIZES:
            assert len(self.samples) == _SPLIT_SIZES[split], f"{task_dir}/{split}: expected {_SPLIT_SIZES[split]} images, got {len(self.samples)}"

    @property
    def num_classes(self):
        return max(lab for _, lab in self.samples) + 1

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label = self.samples[idx]
        return self.transform(default_loader(path)), label

# %% [markdown]
# ## 5. Helpers -- meters, accuracy, LR schedule, feature extraction, cached training
#
# Copied from [cifar-finetuning.ipynb](cifar-finetuning.ipynb). `iterate_batches` keeps
# every sample (no `drop_last`) since the train split is only 1000 images.

# %%
class AverageMeter(object):
    def __init__(self, name, fmt=':f'):
        self.name = name; self.fmt = fmt; self.reset()
    def reset(self):
        self.val = 0; self.avg = 0; self.sum = 0; self.count = 0
    def update(self, val, n=1):
        self.val = val; self.sum += val * n; self.count += n; self.avg = self.sum / self.count


def accuracy(output, target, topk=(1,)):
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)
        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))
        return [correct[:k].reshape(-1).float().sum(0, keepdim=True).mul_(100.0 / batch_size)
                for k in topk]


def adjust_learning_rate(optimizer, init_lr, epoch, total_epochs):
    cur_lr = init_lr * 0.5 * (1. + math.cos(math.pi * epoch / total_epochs))
    for param_group in optimizer.param_groups:
        param_group['lr'] = cur_lr
    return cur_lr


@torch.no_grad()
def extract_features(loader, model, device):
    model.eval()
    feats, labels = [], []
    for images, target in loader:
        images = images.to(device, non_blocking=True)
        f = model.embed(images)
        feats.append(f.cpu()); labels.append(target)
    return torch.cat(feats), torch.cat(labels)


def iterate_batches(feats, labels, batch_size, shuffle):
    n = feats.shape[0]
    idx = torch.randperm(n, device=feats.device) if shuffle else torch.arange(n, device=feats.device)
    for start in range(0, n, batch_size):   # keep all samples (1000-image train split)
        sel = idx[start:start + batch_size]
        yield feats[sel], labels[sel]


@torch.no_grad()
def evaluate_cached(classifier, criterion, feats, labels, batch_size):
    classifier.eval()
    losses = AverageMeter('Loss'); top1 = AverageMeter('Acc@1')
    for x, y in iterate_batches(feats, labels, batch_size, shuffle=False):
        logits = classifier(x)
        loss = criterion(logits, y)
        (a1,) = accuracy(logits, y, topk=(1,))
        losses.update(loss.item(), x.size(0)); top1.update(a1.item(), x.size(0))
    return losses.avg, top1.avg

# %% [markdown]
# ## 6. Run linear probing on each task (train800val200 -> test)
#
# For each task: load the train/test splits from the bundle, extract features through
# the shared frozen backbone, then train a fresh `nn.Linear(192, num_classes)` on the
# cache. Per-task and mean top-1 are collected in `results`.

# %%
def run_task(task, model, device, args):
    tr_ds = VtabImageDataset(args.data_root, task, args.train_split, eval_transform)
    te_ds = VtabImageDataset(args.data_root, task, args.test_split, eval_transform)
    num_classes = max(tr_ds.num_classes, te_ds.num_classes)
    print(f"\n===== {task}  ({num_classes} classes) =====")
    print(f'   {len(tr_ds)} train + {len(te_ds)} test images (disk-backed, lazy load)')

    # num_workers=0: VtabImageDataset is defined in this notebook, so spawned
    # DataLoader workers on macOS can't import it to unpickle. Feature extraction
    # is a single pass, so in-process disk loading is fine here. (To use workers,
    # move VtabImageDataset into moco_tiny/loader.py like CachedMoCoDataset.)
    pin = (device.type == 'cuda')
    tr_loader = torch.utils.data.DataLoader(tr_ds, batch_size=args.batch_size, shuffle=False, num_workers=0, pin_memory=pin)
    te_loader = torch.utils.data.DataLoader(te_ds, batch_size=args.batch_size, shuffle=False, num_workers=0, pin_memory=pin)

    # one-shot feature extraction through the shared frozen backbone
    train_feats, train_labels = extract_features(tr_loader, model, device)
    test_feats,  test_labels  = extract_features(te_loader, model, device)
    train_feats = train_feats.to(device); train_labels = train_labels.to(device)
    test_feats  = test_feats.to(device);  test_labels  = test_labels.to(device)

    # fresh linear classifier on the cached features
    embed_dim = train_feats.shape[1]
    classifier = nn.Linear(embed_dim, num_classes).to(device)
    classifier.weight.data.normal_(mean=0.0, std=0.01)
    classifier.bias.data.zero_()
    criterion = nn.CrossEntropyLoss().to(device)

    init_lr = args.lr * args.batch_size / 256
    optimizer = torch.optim.SGD(classifier.parameters(), init_lr, momentum=args.momentum, weight_decay=args.weight_decay)

    hist = dict(train_loss=[], train_acc=[], test_acc=[])
    best_acc1 = 0.0
    for epoch in range(args.epochs):
        cur_lr = adjust_learning_rate(optimizer, init_lr, epoch, args.epochs)
        classifier.train()
        losses = AverageMeter('Loss'); top1 = AverageMeter('Acc@1')
        for x, y in iterate_batches(train_feats, train_labels, args.batch_size, shuffle=True):
            logits = classifier(x); loss = criterion(logits, y)
            (a1,) = accuracy(logits, y, topk=(1,))
            losses.update(loss.item(), x.size(0)); top1.update(a1.item(), x.size(0))
            optimizer.zero_grad(); loss.backward(); optimizer.step()
        te_loss, te_acc1 = evaluate_cached(classifier, criterion, test_feats, test_labels, args.batch_size)
        hist['train_loss'].append(losses.avg); hist['train_acc'].append(top1.avg)
        hist['test_acc'].append(te_acc1)
        best_acc1 = max(best_acc1, te_acc1)
        if epoch % 10 == 0 or epoch == args.epochs - 1:
            print(f'   epoch {epoch:3d}  lr={cur_lr:.4f}  train@1={top1.avg:6.2f}  test@1={te_acc1:6.2f}')
    print(f'   => {task}: best test top-1 = {best_acc1:.2f}%  (final {hist["test_acc"][-1]:.2f}%)')
    return dict(best_acc1=best_acc1, final_acc1=hist['test_acc'][-1], num_classes=num_classes, hist=hist)


results = {}
overall_t0 = time.time()
for _dir in VTAB_TASKS:
    results[_dir] = run_task(_dir, model, device, args)
print(f'\n=> all {len(results)} tasks done in {time.time()-overall_t0:.1f}s')
# Out:
# ===== caltech101  (102 classes) =====
#    1000 train + 6085 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1=  3.60  test@1= 23.63
#    epoch  10  lr=0.0970  train@1= 87.00  test@1= 52.80
#    epoch  20  lr=0.0883  train@1= 99.30  test@1= 54.07
#    epoch  30  lr=0.0750  train@1=100.00  test@1= 54.02
#    epoch  40  lr=0.0587  train@1=100.00  test@1= 53.99
#    epoch  50  lr=0.0413  train@1=100.00  test@1= 54.23
#    epoch  60  lr=0.0250  train@1=100.00  test@1= 54.25
#    epoch  70  lr=0.0117  train@1=100.00  test@1= 54.25
#    epoch  80  lr=0.0030  train@1=100.00  test@1= 54.23
#    epoch  89  lr=0.0000  train@1=100.00  test@1= 54.23
#    => caltech101: best test top-1 = 54.49%  (final 54.23%)
#
# ===== cifar  (100 classes) =====
#    1000 train + 10000 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1=  2.20  test@1=  6.28
#    epoch  10  lr=0.0970  train@1= 69.70  test@1= 18.21
#    epoch  20  lr=0.0883  train@1= 90.70  test@1= 18.28
#    epoch  30  lr=0.0750  train@1= 96.70  test@1= 18.36
#    epoch  40  lr=0.0587  train@1= 98.30  test@1= 18.39
#    epoch  50  lr=0.0413  train@1= 99.10  test@1= 18.30
#    epoch  60  lr=0.0250  train@1= 99.50  test@1= 18.36
#    epoch  70  lr=0.0117  train@1= 99.50  test@1= 18.28
#    epoch  80  lr=0.0030  train@1= 99.50  test@1= 18.32
#    epoch  89  lr=0.0000  train@1= 99.50  test@1= 18.31
#    => cifar: best test top-1 = 18.62%  (final 18.31%)
#
# ===== dtd  (47 classes) =====
#    1000 train + 1880 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1=  6.70  test@1= 15.43
#    epoch  10  lr=0.0970  train@1= 70.40  test@1= 32.29
#    epoch  20  lr=0.0883  train@1= 85.00  test@1= 32.07
#    epoch  30  lr=0.0750  train@1= 92.30  test@1= 31.81
#    epoch  40  lr=0.0587  train@1= 94.50  test@1= 31.76
#    epoch  50  lr=0.0413  train@1= 96.70  test@1= 31.22
#    epoch  60  lr=0.0250  train@1= 96.90  test@1= 31.28
#    epoch  70  lr=0.0117  train@1= 97.30  test@1= 31.17
#    epoch  80  lr=0.0030  train@1= 97.20  test@1= 31.12
#    epoch  89  lr=0.0000  train@1= 97.20  test@1= 31.12
#    => dtd: best test top-1 = 32.39%  (final 31.12%)
#
# ===== oxford_flowers102  (102 classes) =====
#    1000 train + 6149 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1=  1.20  test@1=  5.11
#    epoch  10  lr=0.0970  train@1= 75.30  test@1= 39.75
#    epoch  20  lr=0.0883  train@1= 90.90  test@1= 43.39
#    epoch  30  lr=0.0750  train@1= 95.80  test@1= 44.87
#    epoch  40  lr=0.0587  train@1= 98.10  test@1= 45.11
#    epoch  50  lr=0.0413  train@1= 99.20  test@1= 45.37
#    epoch  60  lr=0.0250  train@1= 99.20  test@1= 45.42
#    epoch  70  lr=0.0117  train@1= 99.50  test@1= 45.50
#    epoch  80  lr=0.0030  train@1= 99.60  test@1= 45.54
#    epoch  89  lr=0.0000  train@1= 99.60  test@1= 45.54
#    => oxford_flowers102: best test top-1 = 45.55%  (final 45.54%)
#
# ===== oxford_iiit_pet  (37 classes) =====
#    1000 train + 3669 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1=  7.40  test@1= 14.20
#    epoch  10  lr=0.0970  train@1= 70.30  test@1= 28.40
#    epoch  20  lr=0.0883  train@1= 85.90  test@1= 28.21
#    epoch  30  lr=0.0750  train@1= 92.10  test@1= 28.40
#    epoch  40  lr=0.0587  train@1= 95.10  test@1= 27.94
#    epoch  50  lr=0.0413  train@1= 97.30  test@1= 28.10
#    epoch  60  lr=0.0250  train@1= 97.60  test@1= 27.96
#    epoch  70  lr=0.0117  train@1= 98.00  test@1= 28.02
#    epoch  80  lr=0.0030  train@1= 98.00  test@1= 28.02
#    epoch  89  lr=0.0000  train@1= 98.10  test@1= 28.05
#    => oxford_iiit_pet: best test top-1 = 28.95%  (final 28.05%)
#
# ===== sun397  (397 classes) =====
#    1000 train + 21750 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1=  1.70  test@1=  2.69
#    epoch  10  lr=0.0970  train@1= 69.40  test@1= 12.50
#    epoch  20  lr=0.0883  train@1= 97.20  test@1= 12.73
#    epoch  30  lr=0.0750  train@1= 99.30  test@1= 12.58
#    epoch  40  lr=0.0587  train@1= 99.80  test@1= 12.53
#    epoch  50  lr=0.0413  train@1=100.00  test@1= 12.51
#    epoch  60  lr=0.0250  train@1=100.00  test@1= 12.44
#    epoch  70  lr=0.0117  train@1=100.00  test@1= 12.42
#    epoch  80  lr=0.0030  train@1=100.00  test@1= 12.42
#    epoch  89  lr=0.0000  train@1=100.00  test@1= 12.42
#    => sun397: best test top-1 = 12.96%  (final 12.42%)
#
# ===== svhn  (10 classes) =====
#    1000 train + 26032 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1= 15.00  test@1= 20.83
#    epoch  10  lr=0.0970  train@1= 37.60  test@1= 28.15
#    epoch  20  lr=0.0883  train@1= 44.80  test@1= 31.60
#    epoch  30  lr=0.0750  train@1= 50.70  test@1= 32.10
#    epoch  40  lr=0.0587  train@1= 55.60  test@1= 31.00
#    epoch  50  lr=0.0413  train@1= 59.20  test@1= 33.35
#    epoch  60  lr=0.0250  train@1= 60.30  test@1= 33.00
#    epoch  70  lr=0.0117  train@1= 62.00  test@1= 32.73
#    epoch  80  lr=0.0030  train@1= 62.80  test@1= 32.62
#    epoch  89  lr=0.0000  train@1= 63.00  test@1= 32.74
#    => svhn: best test top-1 = 33.35%  (final 32.74%)
#
# ===== eurosat  (10 classes) =====
#    1000 train + 5400 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1= 38.80  test@1= 70.85
#    epoch  10  lr=0.0970  train@1= 89.90  test@1= 81.98
#    epoch  20  lr=0.0883  train@1= 95.50  test@1= 82.94
#    epoch  30  lr=0.0750  train@1= 97.10  test@1= 83.24
#    epoch  40  lr=0.0587  train@1= 98.10  test@1= 83.02
#    epoch  50  lr=0.0413  train@1= 98.90  test@1= 83.15
#    epoch  60  lr=0.0250  train@1= 99.10  test@1= 83.22
#    epoch  70  lr=0.0117  train@1= 99.20  test@1= 83.22
#    epoch  80  lr=0.0030  train@1= 99.20  test@1= 83.19
#    epoch  89  lr=0.0000  train@1= 99.20  test@1= 83.22
#    => eurosat: best test top-1 = 83.39%  (final 83.22%)
#
# ===== patch_camelyon  (2 classes) =====
#    1000 train + 32768 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1= 67.30  test@1= 79.14
#    epoch  10  lr=0.0970  train@1= 77.80  test@1= 66.52
#    epoch  20  lr=0.0883  train@1= 83.80  test@1= 73.30
#    epoch  30  lr=0.0750  train@1= 84.10  test@1= 76.47
#    epoch  40  lr=0.0587  train@1= 84.90  test@1= 77.42
#    epoch  50  lr=0.0413  train@1= 82.90  test@1= 76.64
#    epoch  60  lr=0.0250  train@1= 85.50  test@1= 76.54
#    epoch  70  lr=0.0117  train@1= 86.10  test@1= 76.72
#    epoch  80  lr=0.0030  train@1= 86.00  test@1= 76.63
#    epoch  89  lr=0.0000  train@1= 85.90  test@1= 76.57
#    => patch_camelyon: best test top-1 = 79.92%  (final 76.57%)
#
# ===== resisc45  (45 classes) =====
#    1000 train + 6300 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1=  5.30  test@1= 13.00
#    epoch  10  lr=0.0970  train@1= 78.10  test@1= 48.21
#    epoch  20  lr=0.0883  train@1= 91.90  test@1= 50.00
#    epoch  30  lr=0.0750  train@1= 96.40  test@1= 50.17
#    epoch  40  lr=0.0587  train@1= 97.80  test@1= 50.24
#    epoch  50  lr=0.0413  train@1= 98.30  test@1= 50.05
#    epoch  60  lr=0.0250  train@1= 98.70  test@1= 50.10
#    epoch  70  lr=0.0117  train@1= 98.80  test@1= 50.11
#    epoch  80  lr=0.0030  train@1= 98.80  test@1= 50.10
#    epoch  89  lr=0.0000  train@1= 98.80  test@1= 50.13
#    => resisc45: best test top-1 = 50.27%  (final 50.13%)
#
# ===== diabetic_retinopathy  (5 classes) =====
#    1000 train + 42670 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1= 58.10  test@1= 73.59
#    epoch  10  lr=0.0970  train@1= 57.80  test@1= 40.29
#    epoch  20  lr=0.0883  train@1= 55.80  test@1= 62.64
#    epoch  30  lr=0.0750  train@1= 71.90  test@1= 63.95
#    epoch  40  lr=0.0587  train@1= 74.70  test@1= 52.90
#    epoch  50  lr=0.0413  train@1= 76.40  test@1= 64.79
#    epoch  60  lr=0.0250  train@1= 77.10  test@1= 68.57
#    epoch  70  lr=0.0117  train@1= 77.90  test@1= 70.25
#    epoch  80  lr=0.0030  train@1= 77.10  test@1= 69.94
#    epoch  89  lr=0.0000  train@1= 77.20  test@1= 69.85
#    => diabetic_retinopathy: best test top-1 = 73.60%  (final 69.85%)
#
# ===== clevr_count  (8 classes) =====
#    1000 train + 15000 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1= 20.10  test@1= 26.73
#    epoch  10  lr=0.0970  train@1= 42.80  test@1= 38.55
#    epoch  20  lr=0.0883  train@1= 51.60  test@1= 33.66
#    epoch  30  lr=0.0750  train@1= 62.80  test@1= 38.74
#    epoch  40  lr=0.0587  train@1= 65.30  test@1= 42.16
#    epoch  50  lr=0.0413  train@1= 67.70  test@1= 42.45
#    epoch  60  lr=0.0250  train@1= 68.90  test@1= 41.85
#    epoch  70  lr=0.0117  train@1= 70.90  test@1= 42.05
#    epoch  80  lr=0.0030  train@1= 71.10  test@1= 41.91
#    epoch  89  lr=0.0000  train@1= 70.80  test@1= 41.91
#    => clevr_count: best test top-1 = 43.02%  (final 41.91%)
#
# ===== clevr_dist  (6 classes) =====
#    1000 train + 15000 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1= 21.70  test@1= 25.33
#    epoch  10  lr=0.0970  train@1= 32.60  test@1= 36.29
#    epoch  20  lr=0.0883  train@1= 44.20  test@1= 37.82
#    epoch  30  lr=0.0750  train@1= 48.80  test@1= 38.80
#    epoch  40  lr=0.0587  train@1= 54.30  test@1= 39.93
#    epoch  50  lr=0.0413  train@1= 55.30  test@1= 40.21
#    epoch  60  lr=0.0250  train@1= 63.30  test@1= 41.01
#    epoch  70  lr=0.0117  train@1= 64.50  test@1= 41.34
#    epoch  80  lr=0.0030  train@1= 65.50  test@1= 41.51
#    epoch  89  lr=0.0000  train@1= 65.60  test@1= 41.55
#    => clevr_dist: best test top-1 = 42.12%  (final 41.55%)
#
# ===== dmlab  (6 classes) =====
#    1000 train + 22735 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1= 22.90  test@1= 25.07
#    epoch  10  lr=0.0970  train@1= 50.90  test@1= 30.99
#    epoch  20  lr=0.0883  train@1= 57.60  test@1= 32.43
#    epoch  30  lr=0.0750  train@1= 60.00  test@1= 31.08
#    epoch  40  lr=0.0587  train@1= 63.30  test@1= 30.71
#    epoch  50  lr=0.0413  train@1= 64.00  test@1= 31.71
#    epoch  60  lr=0.0250  train@1= 67.10  test@1= 31.84
#    epoch  70  lr=0.0117  train@1= 67.10  test@1= 31.42
#    epoch  80  lr=0.0030  train@1= 67.80  test@1= 31.47
#    epoch  89  lr=0.0000  train@1= 68.00  test@1= 31.41
#    => dmlab: best test top-1 = 32.64%  (final 31.41%)
#
# ===== kitti  (4 classes) =====
#    1000 train + 711 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1= 42.00  test@1= 37.83
#    epoch  10  lr=0.0970  train@1= 65.70  test@1= 43.74
#    epoch  20  lr=0.0883  train@1= 79.80  test@1= 46.55
#    epoch  30  lr=0.0750  train@1= 74.50  test@1= 45.29
#    epoch  40  lr=0.0587  train@1= 80.70  test@1= 46.13
#    epoch  50  lr=0.0413  train@1= 84.80  test@1= 45.01
#    epoch  60  lr=0.0250  train@1= 84.60  test@1= 44.30
#    epoch  70  lr=0.0117  train@1= 84.90  test@1= 43.88
#    epoch  80  lr=0.0030  train@1= 85.00  test@1= 44.02
#    epoch  89  lr=0.0000  train@1= 85.10  test@1= 43.88
#    => kitti: best test top-1 = 48.38%  (final 43.88%)
#
# ===== dsprites_loc  (16 classes) =====
#    1000 train + 73728 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1=  6.70  test@1=  6.34
#    epoch  10  lr=0.0970  train@1= 15.80  test@1= 10.94
#    epoch  20  lr=0.0883  train@1= 23.40  test@1= 12.18
#    epoch  30  lr=0.0750  train@1= 26.20  test@1= 14.44
#    epoch  40  lr=0.0587  train@1= 32.50  test@1= 14.50
#    epoch  50  lr=0.0413  train@1= 36.50  test@1= 15.52
#    epoch  60  lr=0.0250  train@1= 37.80  test@1= 15.71
#    epoch  70  lr=0.0117  train@1= 40.60  test@1= 15.98
#    epoch  80  lr=0.0030  train@1= 41.60  test@1= 16.03
#    epoch  89  lr=0.0000  train@1= 41.40  test@1= 16.00
#    => dsprites_loc: best test top-1 = 16.06%  (final 16.00%)
#
# ===== dsprites_ori  (16 classes) =====
#    1000 train + 73728 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1=  8.70  test@1=  8.51
#    epoch  10  lr=0.0970  train@1= 17.20  test@1= 14.11
#    epoch  20  lr=0.0883  train@1= 25.80  test@1= 14.32
#    epoch  30  lr=0.0750  train@1= 31.10  test@1= 15.56
#    epoch  40  lr=0.0587  train@1= 32.60  test@1= 17.05
#    epoch  50  lr=0.0413  train@1= 38.00  test@1= 17.20
#    epoch  60  lr=0.0250  train@1= 39.40  test@1= 17.66
#    epoch  70  lr=0.0117  train@1= 41.60  test@1= 17.82
#    epoch  80  lr=0.0030  train@1= 41.40  test@1= 17.95
#    epoch  89  lr=0.0000  train@1= 41.00  test@1= 17.99
#    => dsprites_ori: best test top-1 = 17.99%  (final 17.99%)
#
# ===== smallnorb_azi  (18 classes) =====
#    1000 train + 12150 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1=  6.90  test@1=  7.18
#    epoch  10  lr=0.0970  train@1= 27.10  test@1= 12.17
#    epoch  20  lr=0.0883  train@1= 38.50  test@1= 12.72
#    epoch  30  lr=0.0750  train@1= 40.60  test@1= 13.53
#    epoch  40  lr=0.0587  train@1= 46.90  test@1= 14.03
#    epoch  50  lr=0.0413  train@1= 51.90  test@1= 14.21
#    epoch  60  lr=0.0250  train@1= 52.50  test@1= 14.21
#    epoch  70  lr=0.0117  train@1= 54.10  test@1= 14.02
#    epoch  80  lr=0.0030  train@1= 54.10  test@1= 14.11
#    epoch  89  lr=0.0000  train@1= 54.70  test@1= 14.07
#    => smallnorb_azi: best test top-1 = 14.26%  (final 14.07%)
#
# ===== smallnorb_ele  (9 classes) =====
#    1000 train + 12150 test images (disk-backed, lazy load)
#    epoch   0  lr=0.1000  train@1= 12.80  test@1= 14.26
#    epoch  10  lr=0.0970  train@1= 26.50  test@1= 17.68
#    epoch  20  lr=0.0883  train@1= 33.60  test@1= 17.69
#    epoch  30  lr=0.0750  train@1= 43.40  test@1= 20.54
#    epoch  40  lr=0.0587  train@1= 44.10  test@1= 21.46
#    epoch  50  lr=0.0413  train@1= 50.40  test@1= 20.60
#    epoch  60  lr=0.0250  train@1= 54.30  test@1= 21.19
#    epoch  70  lr=0.0117  train@1= 54.60  test@1= 21.23
#    epoch  80  lr=0.0030  train@1= 54.80  test@1= 21.34
#    epoch  89  lr=0.0000  train@1= 54.90  test@1= 21.33
#    => smallnorb_ele: best test top-1 = 22.01%  (final 21.33%)
#
# => all 19 tasks done in 180.6s

# %% [markdown]
# ## 7. Summary

# %%
print(f'{"task":<20}{"classes":>8}{"best@1":>9}{"final@1":>9}')
print('-' * 46)
for name, r in results.items():
    print(f'{name:<20}{r["num_classes"]:>8}{r["best_acc1"]:>9.2f}{r["final_acc1"]:>9.2f}')
mean_best = sum(r['best_acc1'] for r in results.values()) / len(results)
mean_final = sum(r['final_acc1'] for r in results.values()) / len(results)
print('-' * 46)
print(f'{"mean":<20}{"":>8}{mean_best:>9.2f}{mean_final:>9.2f}')
# Out:
# task                 classes   best@1  final@1
# ----------------------------------------------
# caltech101               102    54.49    54.23
# cifar                    100    18.62    18.31
# dtd                       47    32.39    31.12
# oxford_flowers102        102    45.55    45.54
# oxford_iiit_pet           37    28.95    28.05
# sun397                   397    12.96    12.42
# svhn                      10    33.35    32.74
# eurosat                   10    83.39    83.22
# patch_camelyon             2    79.92    76.57
# resisc45                  45    50.27    50.13
# diabetic_retinopathy       5    73.60    69.85
# clevr_count                8    43.02    41.91
# clevr_dist                 6    42.12    41.55
# dmlab                      6    32.64    31.41
# kitti                      4    48.38    43.88
# dsprites_loc              16    16.06    16.00
# dsprites_ori              16    17.99    17.99
# smallnorb_azi             18    14.26    14.07
# smallnorb_ele              9    22.01    21.33
# ----------------------------------------------
# mean                            39.47    38.44

# %% [markdown]
# ## 8. Curves

# %%
import matplotlib.pyplot as plt

n = len(results)
fig, axes = plt.subplots(1, n, figsize=(4 * n, 4), squeeze=False)
for ax, (name, r) in zip(axes[0], results.items()):
    ep = range(len(r['hist']['test_acc']))
    ax.plot(ep, r['hist']['train_acc'], label='train@1')
    ax.plot(ep, r['hist']['test_acc'],  label='test@1')
    ax.set_title(f'{name} (best {r["best_acc1"]:.1f}%)')
    ax.set_xlabel('epoch'); ax.set_ylabel('accuracy (%)')
    ax.grid(True, alpha=0.3); ax.legend()
plt.tight_layout(); plt.show()
